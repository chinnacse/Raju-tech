# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image in COLOR
image = cv2.imread("348106.jpg")


# Prewitt kernels
prewitt_x_kernel = np.array([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1]
], dtype=np.float32)

prewitt_y_kernel = np.array([
    [-1, -1, -1],
    [ 0,  0,  0],
    [ 1,  1,  1]
], dtype=np.float32)

# Apply Prewitt X directly to the COLOR image
prewitt_x = cv2.filter2D(image, cv2.CV_32F, prewitt_x_kernel)

# Apply Prewitt Y directly to the COLOR image
prewitt_y = cv2.filter2D(image, cv2.CV_32F, prewitt_y_kernel)

# Calculate gradient magnitude
prewitt = cv2.magnitude(prewitt_x, prewitt_y)

# Convert results to 8-bit
prewitt_x = cv2.convertScaleAbs(prewitt_x)
prewitt_y = cv2.convertScaleAbs(prewitt_y)
prewitt = cv2.convertScaleAbs(prewitt)


# Display
plt.figure(figsize=(16, 5))

plt.subplot(1, 4, 1)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(prewitt_x_rgb)
plt.title("Prewitt X")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(prewitt_y_rgb)
plt.title("Prewitt Y")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(prewitt_rgb)
plt.title("Prewitt Edge")
plt.axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 46
#      43 plt.axis("off")
#      45 plt.subplot(1, 4, 2)
# ---> 46 plt.imshow(prewitt_x_grayscale)
#      47 plt.title("Prewitt X")
#      48 plt.axis("off")
#
# NameError: name 'prewitt_x_grayscale' is not defined
